# %% [markdown]
# PYTN_1_078_Layli Rahmania Y (https://github.com/layliry/tugas1)
# # Project Visualisasi

# %% [markdown]
# <img src = "https://global-uploads.webflow.com/5f0d53c042a9ed6288de7f8d/5f6337ae2cfaa10946ceeb06_Hacktiv8%20logo%20horizontal%2001%20black-p-500.png" width = 400>
# <h1 align=center><font size = 5>Hacktiv8 PTP Introduction to Data Science Projects 1 // Publication-Grade Plot</font></h1>

# %% [markdown]
# Title: Hacktiv8 PTP Introduction to Data Science Projects 1: Publication-Grade Plot\

# %% [markdown]
# ## Publication-grade Plot Introduction
#
# The aim of this projects is to introduce you to data visualization with Python as concrete and as consistent as possible. Using what you’ve learned; download the London Crime Dataset from Kaggle. This dataset is a record of crime in major metropolitan areas, such as London, occurs in distinct patterns. This data covers the number of criminal reports by month, LSOA borough, and major/minor category from Jan 2008-Dec 2016.
#
# This dataset contains:
#
# * `lsoa_code`: this represents a policing area
# * `borough`: the london borough for which the statistic is related
# * `major_category`: the major crime category
# * `minor_category`: the minor crime category
# * `value`: the count of the crime for that particular borough, in that particular month
# * `year`: the year of the summary statistic
# * `month`: the month of the summary statistic
#
# Formulate a question and derive a statistical hypothesis test to answer the question. You have to demonstrate that you’re able to make decisions using data in a scientific manner. And the important things, Visualized the data. Examples of questions can be:
#
# * What is the change in the number of crime incidents from 2011 to 2016?
# * What were the top 3 crimes per borough in 2016?
#
# Please make sure that you have completed the session for this course, namely Advanced Visualization which is part of this Program.
#
# Note: You can take a look at Project Rubric below:
#
# Criteria |	Meet Expectations
# ---|---
# Area Plot |	Mengimplementasikan Area Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik
# Histogram |	Mengimplementasikan Histogram Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Bar Chart | Mengimplementasikan Bar Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Pie Chart |	Mengimplementasikan Pie Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Box Plot |	Mengimplementasikan Box Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Scatter Plot |	Mengimplementasikan Scatter Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Word Clouds |	Mengimplementasikan Word Clouds Menggunakan `Wordclouds` Library Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
# Folium Maps |	Mengimplementasikan London Maps Menggunakan `Folium`.
# Preprocessing |	Student Melakukan Preproses Dataset Sebelum Menerapkan Visualisasi. | | Apakah Kode Berjalan Tanpa Ada Eror?
# Apakah Kode Berjalan Tanpa Ada Eror? |	Seluruh Kode Berfungsi Dan Dibuat Dengan Benar.
# Area Plot |	Menarik Informasi/Kesimpulan Berdasarkan Area Plot Yang Telah Student Buat
# Histogram |	Menarik Informasi/Kesimpulan Berdasarkan Histogram Yang Telah Student Buat
# Bar Chart |	Menarik Informasi/Kesimpulan Berdasarkan Bar Chart Yang Telah Student Buat
# Pie Chart |	Menarik Informasi/Kesimpulan Berdasarkan Pie Chart Yang Telah Student Buat
# Box Plot |	Menarik Informasi/Kesimpulan Berdasarkan Box Plot Yang Telah Student Buat
# Scatter Plot |	Menarik Informasi/Kesimpulan Berdasarkan Scatter Plot Yang Telah Student Buat
# Overall Analysis |	Menarik Informasi/Kesimpulan Dari Keseluruhan Plot Yang Dapat Menjawab Hipotesis.
#
# **Focus on "Graded-Function" sections.**
#
# ------------

# %% [markdown]
# ## Exploring Datasets with *pandas* <a id="0"></a>
#
# *pandas* is an essential data analysis toolkit for Python. From their [website](http://pandas.pydata.org/):
# >*pandas* is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, **real world** data analysis in Python.
#
# The course heavily relies on *pandas* for data wrangling, analysis, and visualization. We encourage you to spend some time and  familizare yourself with the *pandas* API Reference: http://pandas.pydata.org/pandas-docs/stable/api.html.

# %% [markdown]
# The first thing we'll do is import two key data analysis modules: *pandas* and **Numpy**.

# %%
# import package python yang akan digunakan
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use(["ggplot"])

df_lc = pd.read_csv("dataset/london_crime_by_lsoa.csv")
df_lc
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# When analyzing a dataset, it's always a good idea to start by getting basic information about your dataframe. We can do this by using the `info()` method.

# %%
# Informasi mengenai data :

df_lc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
# Informasi pada data :
# 1. Kode LSOA | class : string
# 2. Wilayah kejadian perkara (borough) | class : string
# 3. Kategori kriminal Mayor (major_category) | class : string
# 4. Kategori kriminal Minor (minor_category) | class : string
# 5. Jumlah kasus pada th tsb dan daerah tsb (value) | class : int
# 6. Tahun kejadian perkara | class : int
# 7. Bulan kejadian perkara | class : int

# %% [markdown]
# To get the list of column headers we can call upon the dataframe's `.columns` parameter.

# %%
df_lc.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %% [markdown]
# Similarly, to get the list of indicies we use the `.index` parameter

# %%
df_lc.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603],
#       dtype=int64)

# %% [markdown]
# To view the dimensions of the dataframe, we use the `.shape` parameter.

# %%
df_lc.shape
# Out:
# (13490604, 7)

# %%
# statistik deskriptif
df_lc.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %%
# tercatat 13.490.600 jenis kriminal
# kriminalitas yang tercatat terjadi pada tahun 2008 - 2016
# cek kejadian terbanyak (309 kejadian)

df_lc[df_lc["value"]==309]
# Out:
#          lsoa_code        borough major_category       minor_category  value  \
# 1608904  E01004234  Tower Hamlets          Drugs  Possession Of Drugs    309
#
#          year  month
# 1608904  2012      6

# %%
# kriminalitas terbanyak adalah kecanduan obat-obatan terlarang di daerah Tower Hamlets pada bulan Juni 2012
df_lc.groupby('major_category').sum().drop(columns=['year','month'])
# Out:
#                                value
# major_category
# Burglary                      754293
# Criminal Damage               630938
# Drugs                         470765
# Fraud or Forgery                5325
# Other Notifiable Offences     106349
# Robbery                       258873
# Sexual Offences                 1273
# Theft and Handling           2661861
# Violence Against the Person  1558081

# %%
# statistik deskriptif ketika sudah digabungkan perkategori
df_lc.groupby('major_category').sum().drop(columns=['year','month']).describe()

# kriminalitas terbanyak selama tahun 2008 - 2016 di London adalah pencurian/pembegalan yakni sebanyak 2.661.861 kasus
# Out:
#               value
# count  9.000000e+00
# mean   7.164176e+05
# std    8.775569e+05
# min    1.273000e+03
# 25%    1.063490e+05
# 50%    4.707650e+05
# 75%    7.542930e+05
# max    2.661861e+06

# %% [markdown]
# ## Visualizing Data using Matplotlib<a id="8"></a>
#
# ### Matplotlib: Standard Python Visualization Library<a id="10"></a>
#
# The primary plotting library we will explore in the course is [Matplotlib](http://matplotlib.org/).  As mentioned on their website:
# >Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# If you are aspiring to create impactful visualization with python, Matplotlib is an essential tool to have at your disposal.

# %% [markdown]
# ## 1. Area Plot
#
# **What is a line plot and why use it?**
#
# An Area chart or area plot is a type of plot which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields. Use line plot when you have a continuous data set. These are best suited for trend-based visualizations of data over a period of time.
#
# **Questions:**
# `Berapa pergerakan jumlah kasus kriminalitas berupa perampokan tahun 2008 - 2016?`

# %%
# Akan dibuat visualisasi mengenai jumlah kriminalitas berupa perampokan tahun 2008 - 2016

# pindahkan kolom major_category menjadi index
df_lndcrime = df_lc.set_index("major_category")
df_lndcrime
# Out:
#                              lsoa_code     borough  \
# major_category
# Burglary                     E01001116     Croydon
# Violence Against the Person  E01001646   Greenwich
# Violence Against the Person  E01000677     Bromley
# Burglary                     E01003774   Redbridge
# Robbery                      E01004563  Wandsworth
# ...                                ...         ...
# Criminal Damage              E01000504       Brent
# Robbery                      E01002504  Hillingdon
# Burglary                     E01004165      Sutton
# Robbery                      E01001134     Croydon
# Violence Against the Person  E01003413      Merton
#
#                                           minor_category  value  year  month
# major_category
# Burglary                     Burglary in Other Buildings      0  2016     11
# Violence Against the Person               Other violence      0  2016     11
# Violence Against the Person               Other violence      0  2015      5
# ...

# %%
df_bul = df_lndcrime.loc["Burglary"]
df_bul
# Out:
#                 lsoa_code    borough               minor_category  value  \
# major_category
# Burglary        E01001116    Croydon  Burglary in Other Buildings      0
# Burglary        E01003774  Redbridge  Burglary in Other Buildings      0
# Burglary        E01001317     Ealing       Burglary in a Dwelling      0
# Burglary        E01000869     Camden  Burglary in Other Buildings      0
# Burglary        E01001600  Greenwich  Burglary in Other Buildings      0
# ...                   ...        ...                          ...    ...
# Burglary        E01000738    Bromley       Burglary in a Dwelling      1
# Burglary        E01000531      Brent       Burglary in a Dwelling      0
# Burglary        E01003154    Lambeth       Burglary in a Dwelling      3
# Burglary        E01003452     Merton  Burglary in Other Buildings      0
# Burglary        E01004165     Sutton       Burglary in a Dwelling      0
#
#                 year  month
# major_category
# Burglary        2016     11
# ...

# %%
df_bul = df_bul.drop(columns=['lsoa_code', 'borough', 'minor_category', 'month'])
df_bul
# Out:
#                 value  year
# major_category
# Burglary            0  2016
# Burglary            0  2016
# Burglary            0  2013
# Burglary            0  2013
# Burglary            0  2016
# ...               ...   ...
# Burglary            1  2009
# Burglary            0  2013
# Burglary            3  2015
# Burglary            0  2014
# Burglary            0  2011
#
# [1043604 rows x 2 columns]

# %%
df_bul = df_bul.set_index('year')
df_bul
# Out:
#       value
# year
# 2016      0
# 2016      0
# 2013      0
# 2013      0
# 2016      0
# ...     ...
# 2009      1
# 2013      0
# 2015      3
# 2014      0
# 2011      0
#
# [1043604 rows x 1 columns]

# %%
df_area = df_bul.groupby('year').sum()
df_area = df_area.rename(columns={"value":"Burglary"})
df_area
# Out:
#       Burglary
# year
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %%
df_area.plot(kind='area', figsize=(15,7))

plt.title("Kasus Perampokan di London")
plt.xlabel("Tahun")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# **Questions:**
# `Bagaimana perbandingan pergerakan jumlah kriminalitas berupa pencurian dan obat-obatan terlarang tahun 2008 - 2016?`

# %%
# Akan dibuat visualisasi mengenai jumlah kriminalitas berupa pencurian dan obat-obatan terlarang tahun 2008 - 2016
df_cd = df_lndcrime.loc["Criminal Damage"]
df_cd = df_cd.drop(columns=['lsoa_code', 'borough', 'minor_category', 'month'])
df_cd = df_cd.set_index('year')
df_cd = df_cd.groupby('year').sum()
df_cd = df_cd.rename(columns={"value":"Criminal Damage"})
df_cd
# Out:
#       Criminal Damage
# year
# 2008            91872
# 2009            85565
# 2010            77897
# 2011            70914
# 2012            62158
# 2013            56206
# 2014            59279
# 2015            62976
# 2016            64071

# %%
# gabungkan
df_area["Criminal Damage"] = df_cd["Criminal Damage"]

df_area
# Out:
#       Burglary  Criminal Damage
# year
# 2008     88092            91872
# 2009     90619            85565
# 2010     86826            77897
# 2011     93315            70914
# 2012     93392            62158
# 2013     87222            56206
# 2014     76053            59279
# 2015     70489            62976
# 2016     68285            64071

# %%
df_area.plot(kind='area', figsize=(13,7), stacked=False)

plt.title("Burgarly and Criminal Damage Case in London")
plt.xlabel("Tahun")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# **Insight:**
#
# Jumlah kasus perampokan di tahun 2012 memuncak, sedangkan kerusakan akibat kriminalitas menurun hingga mencapai titik terendah di tahu 2013. Apabila dibandingkan, kedua jenis kriminalitas ini pergerakannya saling berbalik terbalik.

# %% [markdown]
# ## 2. Bar Chart
#
# A bar plot is a way of representing data where the *length* of the bars represents the magnitude/size of the feature/variable. Bar graphs usually represent numerical and categorical variables grouped in intervals.
#
# To create a bar plot, we can pass one of two arguments via `kind` parameter in `plot()`:
#
# * `kind=bar` creates a *vertical* bar plot
# * `kind=barh` creates a *horizontal* bar plot
#
# **Question:**
#
# `Bagaimana jumlah kriminalitas pada tahun 2014 untuk setiap macam kejahatan di London?`

# %%
# Akan dibuat visualisasi mengenai jumlah kriminalitas pada tahun 2008 - 2016 
# untuk setiap major_category pada tahun 2015

df_2014 = df_lndcrime[df_lndcrime["year"]==2014]
df_2014
# Out:
#                     lsoa_code               borough  \
# major_category
# Robbery             E01003852  Richmond upon Thames
# Theft and Handling  E01001193               Croydon
# Theft and Handling  E01000280                Barnet
# Theft and Handling  E01000510                 Brent
# Robbery             E01000808               Bromley
# ...                       ...                   ...
# Drugs               E01004620            Wandsworth
# Fraud or Forgery    E01004020             Southwark
# Burglary            E01003452                Merton
# Theft and Handling  E01004531            Wandsworth
# Theft and Handling  E01000588                 Brent
#
#                                    minor_category  value  year  month
# major_category
# Robbery                         Personal Property      0  2014      1
# Theft and Handling                    Other Theft      1  2014      5
# Theft and Handling  Theft/Taking Of Motor Vehicle      0  2014      3
# ...

# %%
df_bar = df_2014.groupby('major_category').sum().drop(columns=['year','month']).rename(columns={"value":"2014"})
df_bar
# Out:
#                                2014
# major_category
# Burglary                      76053
# Criminal Damage               59279
# Drugs                         44435
# Fraud or Forgery                  0
# Other Notifiable Offences     13037
# Robbery                       22150
# Sexual Offences                   0
# Theft and Handling           279880
# Violence Against the Person  185349

# %%
df_bar.plot(figsize=(13,5), kind="bar")

plt.title("2014 Criminal Case in London")
plt.xlabel("Major Category")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# **Question:**
#
# `Bagaimana jumlah kriminalitas pada tahun 2014 - 2016 untuk setiap macam kejahatan di London?`

# %%
# Akan dibuat visualisasi mengenai jumlah kriminalitas 2014, 2015, dan 2016

df_2015 = df_lndcrime[df_lndcrime["year"]==2015]
df_2015 = df_2015.groupby('major_category').sum().drop(columns=['year','month']).rename(columns={"value":"2015"})
df_2015
# Out:
#                                2015
# major_category
# Burglary                      70489
# Criminal Damage               62976
# Drugs                         39785
# Fraud or Forgery                  0
# Other Notifiable Offences     14229
# Robbery                       21383
# Sexual Offences                   0
# Theft and Handling           284022
# Violence Against the Person  218740

# %%
df_2016 = df_lndcrime[df_lndcrime["year"]==2015]
df_2016 = df_2016.groupby('major_category').sum().drop(columns=['year','month']).rename(columns={"value":"2016"})
df_2016
# Out:
#                                2016
# major_category
# Burglary                      70489
# Criminal Damage               62976
# Drugs                         39785
# Fraud or Forgery                  0
# Other Notifiable Offences     14229
# Robbery                       21383
# Sexual Offences                   0
# Theft and Handling           284022
# Violence Against the Person  218740

# %%
# gabungkan
df_bar["2015"] = df_2015["2015"]
df_bar["2016"] = df_2016["2016"]
df_bar
# Out:
#                                2014    2015    2016
# major_category
# Burglary                      76053   70489   70489
# Criminal Damage               59279   62976   62976
# Drugs                         44435   39785   39785
# Fraud or Forgery                  0       0       0
# Other Notifiable Offences     13037   14229   14229
# Robbery                       22150   21383   21383
# Sexual Offences                   0       0       0
# Theft and Handling           279880  284022  284022
# Violence Against the Person  185349  218740  218740

# %%
df_bar.plot(kind='bar', figsize=(13,7))

plt.title("2014-2016 Criminal Case in London")
plt.xlabel("Major Category")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# **Insight:**
#
# Selama tahun 2014-2016 tidak terjadi perubahan yang signifikan untuk setiap jenis kriminalitas.

# %% [markdown]
# ## 3. Pie Chart
# A `pie chart` is a circualr graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
#
# **Question:**
#
# `Bagaimana proporsi kriminalitas di london pada tahun 2008 - 2016?`

# %%
# akan divisualisasikan untuk banyaknya case setiap category di tahun 2008 - 2016
df_pie = df_lndcrime.groupby('major_category')["value"].sum()
df_pie
# Out:
# major_category
# Burglary                        754293
# Criminal Damage                 630938
# Drugs                           470765
# Fraud or Forgery                  5325
# Other Notifiable Offences       106349
# Robbery                         258873
# Sexual Offences                   1273
# Theft and Handling             2661861
# Violence Against the Person    1558081
# Name: value, dtype: int64

# %%
df_pie.plot(kind="pie",
            figsize=(6,6),
            startangle=55)
# Out:
# <AxesSubplot:ylabel='value'>

# %%
df_pie.plot(kind="pie",subplots=True,
            figsize=(13,5),
            label = None,
             autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='value'>], dtype=object)

# %% [markdown]
# **Insight:**
#
# Jenis kriminalitas yang paling banyak terjadi di London pada tahun 2008-2016 adalah Theft and Handling.

# %% [markdown]
# ## 4. Scatter Plot

# %%
# apakah ada korelasi antara penggunaan obat-obatan terlarang dengan Criminal Damage?
titles = list(df_lc)
titles
# Out:
# ['lsoa_code',
#  'borough',
#  'major_category',
#  'minor_category',
#  'value',
#  'year',
#  'month']

# %%
titles[0],titles[2]=titles[2],titles[0]
titles
# Out:
# ['major_category',
#  'borough',
#  'lsoa_code',
#  'minor_category',
#  'value',
#  'year',
#  'month']

# %%
df_lc = df_lc[titles]
df_lc
# Out:
#                        major_category     borough  lsoa_code  \
# 0                            Burglary     Croydon  E01001116
# 1         Violence Against the Person   Greenwich  E01001646
# 2         Violence Against the Person     Bromley  E01000677
# 3                            Burglary   Redbridge  E01003774
# 4                             Robbery  Wandsworth  E01004563
# ...                               ...         ...        ...
# 13490599              Criminal Damage       Brent  E01000504
# 13490600                      Robbery  Hillingdon  E01002504
# 13490601                     Burglary      Sutton  E01004165
# 13490602                      Robbery     Croydon  E01001134
# 13490603  Violence Against the Person      Merton  E01003413
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
df_lc = df_lc.drop(columns=['borough','lsoa_code','minor_category','month'])
df_lc = df_lc.set_index('major_category')
df_lc
# Out:
#                              value  year
# major_category
# Burglary                         0  2016
# Violence Against the Person      0  2016
# Violence Against the Person      0  2015
# Burglary                         0  2016
# Robbery                          0  2008
# ...                            ...   ...
# Criminal Damage                  0  2015
# Robbery                          1  2015
# Burglary                         0  2011
# Robbery                          0  2011
# Violence Against the Person      0  2015
#
# [13490604 rows x 2 columns]

# %%
titles = list(df_lc)
titles[0],titles[1]=titles[1],titles[0]
df_lc = df_lc[titles]
df_lc
# Out:
#                              year  value
# major_category
# Burglary                     2016      0
# Violence Against the Person  2016      0
# Violence Against the Person  2015      0
# Burglary                     2016      0
# Robbery                      2008      0
# ...                           ...    ...
# Criminal Damage              2015      0
# Robbery                      2015      1
# Burglary                     2011      0
# Robbery                      2011      0
# Violence Against the Person  2015      0
#
# [13490604 rows x 2 columns]

# %%
df_2008 = df_lc[df_lc["year"]==2008]
df_2008 = df_2008.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2008"})

df_2009 = df_lc[df_lc["year"]==2009]
df_2009 = df_2009.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2009"})

df_2010 = df_lc[df_lc["year"]==2010]
df_2010 = df_2010.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2010"})

df_2011 = df_lc[df_lc["year"]==2011]
df_2011 = df_2011.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2011"})

df_2012 = df_lc[df_lc["year"]==2012]
df_2012 = df_2012.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2012"})

df_2013 = df_lc[df_lc["year"]==2013]
df_2013 = df_2013.groupby('major_category').sum().drop(columns=['year']).rename(columns={"value":"2013"})

df_bar["2008"] = df_2008["2008"]
df_bar["2009"] = df_2009["2009"]
df_bar["2010"] = df_2010["2010"]
df_bar["2011"] = df_2011["2011"]
df_bar["2012"] = df_2012["2012"]
df_bar["2013"] = df_2013["2013"]

df_sc = df_bar
df_sc

titles = list(df_sc)
titles[0],titles[1],titles[2],titles[3],titles[4],titles[5],titles[6],titles[7],titles[8]=titles[3],titles[4],titles[5],titles[6],titles[7],titles[8],titles[0],titles[1],titles[2]
df_sc = df_sc[titles]

df_sc
# Out:
#                                2008    2009    2010    2011    2012    2013  \
# major_category
# Burglary                      88092   90619   86826   93315   93392   87222
# Criminal Damage               91872   85565   77897   70914   62158   56206
# Drugs                         68804   60549   58674   57550   51776   50278
# Fraud or Forgery               5325       0       0       0       0       0
# Other Notifiable Offences     10112   10644   10768   10264   10675   10811
# Robbery                       29627   29568   32341   36679   35260   29337
# Sexual Offences                1273       0       0       0       0       0
# Theft and Handling           283692  279492  290924  309292  334054  306372
# Violence Against the Person  159844  160777  157894  146901  150014  146181
#
#                                2014    2015    2016
# major_category
# Burglary                      76053   70489   70489
# Criminal Damage               59279   62976   62976
# ...

# %%
df_sc = df_sc.loc[["Criminal Damage","Drugs"],:].T
df_sc
# Out:
# major_category  Criminal Damage  Drugs
# 2008                      91872  68804
# 2009                      85565  60549
# 2010                      77897  58674
# 2011                      70914  57550
# 2012                      62158  51776
# 2013                      56206  50278
# 2014                      59279  44435
# 2015                      62976  39785
# 2016                      62976  39785

# %%
df_sc.plot(kind="scatter", 
            x="Criminal Damage", 
            y="Drugs",
            figsize=(11,5))

plt.title("Korelasi Jumlah Kasus Kecanduan dan Jumlah Kasus Kerusakan akibat Kriminalitas")
# Out:
# Text(0.5, 1.0, 'Korelasi Jumlah Kasus Kecanduan dan Jumlah Kasus Kerusakan akibat Kriminalitas')

# %%
df_scyear = df_sc.reset_index()
df_scyear = df_scyear.rename(columns={"index":"year"})
df_scyear
# Out:
# major_category  year  Criminal Damage  Drugs
# 0               2008            91872  68804
# 1               2009            85565  60549
# 2               2010            77897  58674
# 3               2011            70914  57550
# 4               2012            62158  51776
# 5               2013            56206  50278
# 6               2014            59279  44435
# 7               2015            62976  39785
# 8               2016            62976  39785

# %%
df_scyear.plot(kind="scatter", x="year", y="Criminal Damage")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Criminal Damage'>

# %%
df_scyear.plot(kind="scatter", x="year", y="Drugs")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Drugs'>

# %%
# gabungkan
fig = plt.figure()
ax0 = fig.add_subplot(1, 2, 1) 
ax1 = fig.add_subplot(1, 2, 2) 

df_scyear.plot(kind="scatter", x="year", y="Criminal Damage", ax=ax0)

df_scyear.plot(kind="scatter", x="year", y="Drugs", ax=ax1)

fig.suptitle("Korelasi Criminal Damage dan Kasus Penggunaan Obat-obatan setiap Tahun")
# Out:
# Text(0.5, 0.98, 'Korelasi Criminal Damage dan Kasus Penggunaan Obat-obatan setiap Tahun')

# %%
# menggabungkan beberapa scatter plot di plot yang sama

plt.figure(figsize=(12,6))
plt.scatter(df_scyear['year'], df_scyear['Criminal Damage'])
plt.scatter(df_scyear['year'], df_scyear['Drugs'])

plt.title("Criminal Damage vs Kasus Penggunaan Obat-obatan")
# Out:
# Text(0.5, 1.0, 'Criminal Damage vs Kasus Penggunaan Obat-obatan')

# %% [markdown]
# **Insight:**
#
# Terdapat korelasi sebanding lurus untuk kasus penggunaan obat-obatan dan kerusakan pada tahun 2008 s.d. 2013, namun pada tahun 2014 - 2016, meskipun kasus kecanduan obat-obatan menurun, justru kerusakan akibat kriminalitas beranjak naik.

# %% [markdown]
# ## 5. Box Plot
#
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# - **Minimun:** Smallest number in the dataset.
# - **First quartile:** Middle number between the `minimum` and the `median`.
# - **Second quartile (Median):** Middle number of the (sorted) dataset.
# - **Third quartile:** Middle number between `median` and `maximum`.
# - **Maximum:** Highest number in the dataset.
#
# **Question:**
#
# `Bagaimana distribusi data perampokan di London setiap bulannya pada 2008-2016?`

# %%
df_lndcrime.reset_index()
# Out:
#                        major_category  lsoa_code     borough  \
# 0                            Burglary  E01001116     Croydon
# 1         Violence Against the Person  E01001646   Greenwich
# 2         Violence Against the Person  E01000677     Bromley
# 3                            Burglary  E01003774   Redbridge
# 4                             Robbery  E01004563  Wandsworth
# ...                               ...        ...         ...
# 13490599              Criminal Damage  E01000504       Brent
# 13490600                      Robbery  E01002504  Hillingdon
# 13490601                     Burglary  E01004165      Sutton
# 13490602                      Robbery  E01001134     Croydon
# 13490603  Violence Against the Person  E01003413      Merton
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
titles = list(df_lndcrime.reset_index())
titles
# Out:
# ['major_category',
#  'lsoa_code',
#  'borough',
#  'minor_category',
#  'value',
#  'year',
#  'month']

# %%
titles[4],titles[5],titles[6]=titles[5],titles[6],titles[4]
titles
# Out:
# ['major_category',
#  'lsoa_code',
#  'borough',
#  'minor_category',
#  'year',
#  'month',
#  'value']

# %%
df_bp = df_lndcrime.reset_index()[titles]
df_bp
# Out:
#                        major_category  lsoa_code     borough  \
# 0                            Burglary  E01001116     Croydon
# 1         Violence Against the Person  E01001646   Greenwich
# 2         Violence Against the Person  E01000677     Bromley
# 3                            Burglary  E01003774   Redbridge
# 4                             Robbery  E01004563  Wandsworth
# ...                               ...        ...         ...
# 13490599              Criminal Damage  E01000504       Brent
# 13490600                      Robbery  E01002504  Hillingdon
# 13490601                     Burglary  E01004165      Sutton
# 13490602                      Robbery  E01001134     Croydon
# 13490603  Violence Against the Person  E01003413      Merton
#
#                        minor_category  year  month  value
# 0         Burglary in Other Buildings  2016     11      0
# 1                      Other violence  2016     11      0
# ...

# %%
df_bp=df_bp.set_index('major_category')
df_bp
# Out:
#                              lsoa_code     borough  \
# major_category
# Burglary                     E01001116     Croydon
# Violence Against the Person  E01001646   Greenwich
# Violence Against the Person  E01000677     Bromley
# Burglary                     E01003774   Redbridge
# Robbery                      E01004563  Wandsworth
# ...                                ...         ...
# Criminal Damage              E01000504       Brent
# Robbery                      E01002504  Hillingdon
# Burglary                     E01004165      Sutton
# Robbery                      E01001134     Croydon
# Violence Against the Person  E01003413      Merton
#
#                                           minor_category  year  month  value
# major_category
# Burglary                     Burglary in Other Buildings  2016     11      0
# Violence Against the Person               Other violence  2016     11      0
# Violence Against the Person               Other violence  2015      5      0
# ...

# %%
df_rob = df_bp.loc["Robbery"]
df_rob
# Out:
#                 lsoa_code               borough     minor_category  year  \
# major_category
# Robbery         E01004563            Wandsworth  Personal Property  2008
# Robbery         E01002633              Hounslow  Personal Property  2013
# Robbery         E01003852  Richmond upon Thames  Personal Property  2014
# Robbery         E01001206                Ealing  Personal Property  2015
# Robbery         E01000808               Bromley  Personal Property  2014
# ...                   ...                   ...                ...   ...
# Robbery         E01002432            Hillingdon  Business Property  2015
# Robbery         E01002497            Hillingdon  Business Property  2015
# Robbery         E01004270         Tower Hamlets  Personal Property  2011
# Robbery         E01002504            Hillingdon  Personal Property  2015
# Robbery         E01001134               Croydon  Business Property  2011
#
#                 month  value
# major_category
# ...

# %%
df_robyear = df_rob.drop(columns=["borough","lsoa_code","minor_category"])
df_robyear
# Out:
#                 year  month  value
# major_category
# Robbery         2008      6      0
# Robbery         2013      4      0
# Robbery         2014      1      0
# Robbery         2015      7      0
# Robbery         2014      6      0
# ...              ...    ...    ...
# Robbery         2015      3      0
# Robbery         2015      3      0
# Robbery         2011      3      5
# Robbery         2015      6      1
# Robbery         2011      5      0
#
# [939384 rows x 3 columns]

# %%
df_robyear = df_robyear.set_index("year").rename(columns={"value":"Robbery"})
df_robyear
# Out:
#       month  Robbery
# year
# 2008      6        0
# 2013      4        0
# 2014      1        0
# 2015      7        0
# 2014      6        0
# ...     ...      ...
# 2015      3        0
# 2015      3        0
# 2011      3        5
# 2015      6        1
# 2011      5        0
#
# [939384 rows x 2 columns]

# %%
df_rob2008 = df_robyear.loc[2008]
df_rob2008 = df_rob2008.groupby("month").sum().reset_index()

df_rob2009 = df_robyear.loc[2009]
df_rob2009 = df_rob2009.groupby("month").sum().reset_index()

df_rob2010 = df_robyear.loc[2010]
df_rob2010 = df_rob2010.groupby("month").sum().reset_index()

df_rob2011 = df_robyear.loc[2011]
df_rob2011 = df_rob2011.groupby("month").sum().reset_index()

df_rob2012 = df_robyear.loc[2012]
df_rob2012 = df_rob2012.groupby("month").sum().reset_index()

df_rob2013 = df_robyear.loc[2013]
df_rob2013 = df_rob2013.groupby("month").sum().reset_index()

df_rob2014 = df_robyear.loc[2014]
df_rob2014 = df_rob2014.groupby("month").sum().reset_index()

df_rob2015 = df_robyear.loc[2015]
df_rob2015 = df_rob2015.groupby("month").sum().reset_index()

df_rob2016 = df_robyear.loc[2016]
df_rob2016 = df_rob2016.groupby("month").sum().reset_index()

df_rob2016
# Out:
#     month  Robbery
# 0       1     1810
# 1       2     1646
# 2       3     1711
# 3       4     1570
# 4       5     1787
# 5       6     1885
# 6       7     1960
# 7       8     1910
# 8       9     1980
# 9      10     2048
# 10     11     1983
# 11     12     2238

# %%
df_robmonth = pd.concat([df_rob2008,df_rob2009,df_rob2010,df_rob2011,df_rob2012,df_rob2013,df_rob2014,df_rob2015,df_rob2016],
                        ignore_index = True)

df_robmonth
# Out:
#      month  Robbery
# 0        1     2887
# 1        2     2455
# 2        3     2585
# 3        4     2498
# 4        5     2490
# ..     ...      ...
# 103      8     1910
# 104      9     1980
# 105     10     2048
# 106     11     1983
# 107     12     2238
#
# [108 rows x 2 columns]

# %%
df_robmonth.set_index("month").plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Question:**
#
# `Bagaimana distribusi data kasus perampokan dan penggunaan obat-obatan terlarang di London setiap bulannya pada 2008-2016?`

# %%
df_drg = df_bp.loc["Drugs"]

df_drgyear = df_drg.drop(columns=["borough","lsoa_code","minor_category"])

df_drgyear = df_drgyear.set_index("year").rename(columns={"value":"Drugs"})

df_drg2008 = df_drgyear.loc[2008]
df_drg2008 = df_drg2008.groupby("month").sum().reset_index()

df_drg2009 = df_drgyear.loc[2009]
df_drg2009 = df_drg2009.groupby("month").sum().reset_index()

df_drg2010 = df_drgyear.loc[2010]
df_drg2010 = df_drg2010.groupby("month").sum().reset_index()

df_drg2011 = df_drgyear.loc[2011]
df_drg2011 = df_drg2011.groupby("month").sum().reset_index()

df_drg2012 = df_drgyear.loc[2012]
df_drg2012 = df_drg2012.groupby("month").sum().reset_index()

df_drg2013 = df_drgyear.loc[2013]
df_drg2013 = df_drg2013.groupby("month").sum().reset_index()

df_drg2014 = df_drgyear.loc[2014]
df_drg2014 = df_drg2014.groupby("month").sum().reset_index()

df_drg2015 = df_drgyear.loc[2015]
df_drg2015 = df_drg2015.groupby("month").sum().reset_index()

df_drg2016 = df_drgyear.loc[2016]
df_drg2016 = df_drg2016.groupby("month").sum().reset_index()

df_drgmonth = pd.concat([df_drg2008,df_drg2009,df_drg2010,df_drg2011,df_drg2012,df_drg2013,df_drg2014,df_drg2015,df_drg2016],
                        ignore_index = True)

df_drgmonth
# Out:
#      month  Drugs
# 0        1   5230
# 1        2   6071
# 2        3   5769
# 3        4   5158
# 4        5   5868
# ..     ...    ...
# 103      8   3442
# 104      9   3091
# 105     10   3204
# 106     11   2894
# 107     12   2656
#
# [108 rows x 2 columns]

# %%
df_robmonth ["Drugs"] = df_drgmonth ["Drugs"]
df_robdrg = df_robmonth

df_robdrg
# Out:
#      month  Robbery  Drugs
# 0        1     2887   5230
# 1        2     2455   6071
# 2        3     2585   5769
# 3        4     2498   5158
# 4        5     2490   5868
# ..     ...      ...    ...
# 103      8     1910   3442
# 104      9     1980   3091
# 105     10     2048   3204
# 106     11     1983   2894
# 107     12     2238   2656
#
# [108 rows x 3 columns]

# %%
df_robdrg.set_index("month").plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Insight:**
#
# Persebaran data pada kasus robbery tiap bulannya lebih condong ke arah minimum, artinya lebih banyak data yang lebih kecil dari rata-ratanya.
#
# Sedangkan persebaran data pada kasus penggunaan obat-obatan terlarang tiap bulannya lebih merata, artinya banyak data yang mendekati nilai rata-ratanya.

# %% [markdown]
# ## Word Clouds <a id="8"></a>
#
#
# `Word` clouds (also known as text clouds or tag clouds) work in a simple way: the more a specific word appears in a source of textual data (such as a speech, blog post, or database), the bigger and bolder it appears in the word cloud.

# %%
# install wordcloud
# !conda install -c conda-forge wordcloud --yes

# !pip install wordcloud

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# ...
# Wordcloud is installed and imported!

# %%
from PIL import Image

# %%
df_boroughtop = df_lndcrime.head(500000)
df_boroughtop
# Out:
#                              lsoa_code               borough  \
# major_category
# Burglary                     E01001116               Croydon
# Violence Against the Person  E01001646             Greenwich
# Violence Against the Person  E01000677               Bromley
# Burglary                     E01003774             Redbridge
# Robbery                      E01004563            Wandsworth
# ...                                ...                   ...
# Drugs                        E01004274         Tower Hamlets
# Violence Against the Person  E01002534            Hillingdon
# Robbery                      E01000541                 Brent
# Violence Against the Person  E01002964  Kingston upon Thames
# Violence Against the Person  E01000057  Barking and Dagenham
#
#                                           minor_category  value  year  month
# major_category
# Burglary                     Burglary in Other Buildings      0  2016     11
# ...

# %%
wc_lndcrime = df_lndcrime.index.values

wc_lndcrime
# Out:
# array(['Burglary', 'Violence Against the Person',
#        'Violence Against the Person', ..., 'Burglary', 'Robbery',
#        'Violence Against the Person'], dtype=object)

# %%
print(len(wc_lndcrime))
# Out:
# 13490604

# %% [markdown]
# `Apa kasus terbanyak pada 500.000 kasus terbanyak?`

# %%
stopwords = set(STOPWORDS)
borough_words = ''
for val in df_boroughtop['borough']:
    val=str(val)
    tokens = val.split()

    for i in range(len(tokens)) :
        tokens[i]=tokens[i].lower()
    
    borough_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                        background_color="white",
                        stopwords = stopwords,
                        min_font_size = 10).generate(borough_words)

plt.figure(figsize =(8,10), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Folium
#
# Folium is a powerful Python library that helps you create several types of Leaflet maps. The fact that the Folium results are interactive makes this library very useful for dashboard building.
#
# From the official Folium documentation page:
#
# > Folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js library. Manipulate your data in Python, then visualize it in on a Leaflet map via Folium.
#
# > Folium makes it easy to visualize data that's been manipulated in Python on an interactive Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.
#
# > The library has a number of built-in tilesets from OpenStreetMap, Mapbox, and Stamen, and supports custom tilesets with Mapbox or Cloudmade API keys. Folium supports both GeoJSON and TopoJSON overlays, as well as the binding of data to those overlays to create choropleth maps with color-brewer color schemes.

# %%
# !pip install folium
import folium

print('Folium installed and imported!')
# Out:
# ...
# Folium installed and imported!

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# define the world map centered around London with a low zoom level 8

london_map = folium.Map(
    location=[51.51549071259008, -0.12086340415411731],
    zoom_start=13,
    tiles="OpenStreetMap"
    )
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
marker_london = folium.Marker(
    location=[51.51549071259008, -0.12086340415411731], 
    popup="London",  # klik baru muncul
    tooltip="London"  # hover sudah muncul
    )
marker_london


lon_mar = london_map.add_child(marker_london)
lon_mar
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_bor = df_lndcrime.groupby('borough').sum().reset_index().drop(columns=['value','year','month'])
df_bor = df_bor.head()
df_bor
# Out:
#                 borough
# 0  Barking and Dagenham
# 1                Barnet
# 2                Bexley
# 3                 Brent
# 4               Bromley

# %%
from pandas import DataFrame

df_loc = DataFrame({'X' :[51.540,51.658,51.452,51.631,51.406], 
                    'Y' :[0.12735,-0.19151,0.11685,0.27966,0.02156]})
df_loc
# Out:
#         X        Y
# 0  51.540  0.12735
# 1  51.658 -0.19151
# 2  51.452  0.11685
# 3  51.631  0.27966
# 4  51.406  0.02156

# %%
df_bor['X']=df_loc['X']
df_bor['Y']=df_loc['Y']

df_bor
# Out:
#                 borough       X        Y
# 0  Barking and Dagenham  51.540  0.12735
# 1                Barnet  51.658 -0.19151
# 2                Bexley  51.452  0.11685
# 3                 Brent  51.631  0.27966
# 4               Bromley  51.406  0.02156

# %%
latitude = 51.41802885053533
longitude = -0.22041729087567286
map_sf = folium.Map(location=[latitude, longitude], zoom_start=12)

# %%
# kita gunakan iterrows() untuk melewati setiap baris data satu per satu
# kita akan pakai lokasi lat dan long serta penjelasan Category untuk membuat 100 marker

for (i, crime) in df_bor.iterrows():
    print(crime["X"], crime["Y"], crime["borough"])
    print()
    crime_marker = folium.Marker(location=[crime["Y"], crime["X"]], popup=crime["borough"])
    map_sf.add_child(crime_marker)
# Out:
# 51.54 0.12735 Barking and Dagenham
#
# 51.658 -0.19151 Barnet
#
# 51.452 0.11685 Bexley
#
# 51.631 0.27966 Brent
#
# 51.406 0.02156 Bromley

# %%
map_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
